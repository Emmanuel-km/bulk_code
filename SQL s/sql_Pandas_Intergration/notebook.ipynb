# %% [markdown]
# Handling sql with pandas

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import sqlite3
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import sqlite3
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
# ...

# %% [markdown]
# setting up the database

# %%
conn = sqlite3.connect('company_sales.db')
c = conn.cursor()

# %%
try:
    c.execute('''
      2 CREATE TABLE sales_data(
      3     date TEXT,
      4     region TEXT,
      5     product TEXT,
      6     quantity INTEGER,
      7     price REAL,
      8     service_receptionist TEXT
      9 )''')
except:
    print("table already created")
# Out:
# table already created

# %%
sales = [
    ("2025-11-01", "North", "Laptop", 5, 1200.50, "Emily Clark"),
    ("2025-11-02", "South", "Smartphone", 10, 699.99, "James Lee"),
    ("2025-11-03", "East", "Headphones", 15, 89.99, "Olivia Brown"),
    ("2025-11-04", "West", "Tablet", 8, 450.00, "Noah Wilson"),
    ("2025-11-05", "Central", "Monitor", 12, 299.49, "Sophia Davis")
]

# %%
c.executemany('INSERT INTO sales_data VALUES (?, ?, ?, ?, ?, ?)', sales)

# %% [markdown]
# now that data is loaded lets query sql

# %%
pd.read_sql_query('SELECT * FROM sales_data', conn)
# Out:
#          date   region     product  quantity    price service_receptionist
# 0  2025-11-01    North      Laptop         5  1200.50          Emily Clark
# 1  2025-11-02    South  Smartphone        10   699.99            James Lee
# 2  2025-11-03     East  Headphones        15    89.99         Olivia Brown
# 3  2025-11-04     West      Tablet         8   450.00          Noah Wilson
# 4  2025-11-05  Central     Monitor        12   299.49         Sophia Davis

# %%
try:
    c.execute('''CREATE TABLE product_details(product_Id INT,product_name TEXT,price REAL )''')
except:
    print("already exixsts")
# Out:
# already exixsts

# %%
pd.read_sql_query('SELECT * FROM product_details', conn)
# Out:
# Empty DataFrame
# Columns: [product_Id, product_name, price]
# Index: []

# %%
products=[(1,"Laptop",1200),
          (2,"Smartphone",699.99),
          (3,"Headphones",89.99),
          (4,"Tablet",450.00),
          (5,"Monitor",299.49)]

# %%
c.executemany('INSERT INTO product_details VALUES (?, ?, ?)', products)

# %%
pd.read_sql_query('SELECT * FROM product_details', conn)
# Out:
#    product_Id product_name    price
# 0           1       Laptop  1200.00
# 1           2   Smartphone   699.99
# 2           3   Headphones    89.99
# 3           4       Tablet   450.00
# 4           5      Monitor   299.49

# %%
try:
    c.execute('''CREATE TABLE service_details(service_receptionist_Id INT,service_receptionist_name TEXT )''')
except:
    print("already exixsts")

# %%
service=[(1,"Emily Clark"),
         (2,"James Lee"),
         (3,"Olivia Brown"),
         (4,"Noah Wilson"),
         (5,"Sophia Davis")]

# %%
c.executemany('INSERT INTO service_details VALUES (?, ?)', service)

# %%
pd.read_sql_query('SELECT * FROM service_details', conn)
# Out:
#    service_receptionist_Id service_receptionist_name
# 0                        1               Emily Clark
# 1                        2                 James Lee
# 2                        3              Olivia Brown
# 3                        4               Noah Wilson
# 4                        5              Sophia Davis
